# %%
import pandas as pd

# %%
school = pd.DataFrame({
    "Yếu tố ảnh hưởng" : ["Mạng xã hội", "Game", "Chất lượng giảng dạy", "Tâm lý", "Khác"],
    "Mức độ ảnh hưởng" : [21,21,8,2,48],
    "Cách giải quyết" : ["Giáo viên tự giải quyết", "Giáo viên tự giải quyết", "Giáo viên tự giải quyết", "Chuyên gia tâm lý hỗ trợ", "Giáo viên tự giải quyết"]
})

school
# Out:
#        Yếu tố ảnh hưởng  Mức độ ảnh hưởng           Cách giải quyết
# 0           Mạng xã hội                21   Giáo viên tự giải quyết
# 1                  Game                21   Giáo viên tự giải quyết
# 2  Chất lượng giảng dạy                 8   Giáo viên tự giải quyết
# 3                Tâm lý                 2  Chuyên gia tâm lý hỗ trợ
# 4                  Khác                48   Giáo viên tự giải quyết
